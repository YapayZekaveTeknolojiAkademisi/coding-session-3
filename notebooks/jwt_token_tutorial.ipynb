# %%
# !pip install PyJWT
# Out:
# Requirement already satisfied: PyJWT in /Users/enesa/Documents/ForAkademi/codding-session-4/.venv/lib/python3.12/site-packages (2.11.0)
#
# [notice] A new release of pip is available: 25.0.1 -> 26.0.1
# [notice] To update, run: pip install --upgrade pip

# %%
import jwt 
from datetime import datetime, timezone, timedelta

# %%
SECRET_KEY = "SUPER-DUPER-SECRET-KEY"
ALGORITHM = "HS256"
EXPIRATION_HOUR = 1

now = datetime.now(timezone.utc)

payload = {
    "sub": "user_id",
    "iat": int(now.timestamp()),
    "exp": int((now + timedelta(hours=EXPIRATION_HOUR)).timestamp()),
    "role": "admin"
}

token = jwt.encode(payload, SECRET_KEY, algorithm=ALGORITHM)
# Out:
# /Users/enesa/Documents/ForAkademi/codding-session-4/.venv/lib/python3.12/site-packages/jwt/api_jwt.py:153: InsecureKeyLengthWarning: The HMAC key is 22 bytes long, which is below the minimum recommended length of 32 bytes for SHA256. See RFC 7518 Section 3.2.
#   return self._jws.encode(

# %%
token
# Out:
# 'eyJhbGciOiJIUzI1NiIsInR5cCI6IkpXVCJ9.eyJzdWIiOiJ1c2VyX2lkIiwiaWF0IjoxNzcwMzk5MDMyLCJleHAiOjE3NzA0MDI2MzIsInJvbGUiOiJhZG1pbiJ9.ZdtUlmqfZCItn5vNjdgEP148jsKfxoB_PJS14NvVxtA'

# %%
decoded = jwt.decode(token, SECRET_KEY, algorithms=[ALGORITHM])
# Out:
# /Users/enesa/Documents/ForAkademi/codding-session-4/.venv/lib/python3.12/site-packages/jwt/api_jwt.py:371: InsecureKeyLengthWarning: The HMAC key is 22 bytes long, which is below the minimum recommended length of 32 bytes for SHA256. See RFC 7518 Section 3.2.
#   decoded = self.decode_complete(

# %%
decoded
# Out:
# {'sub': 'user_id', 'iat': 1770399032, 'exp': 1770402632, 'role': 'admin'}

# %%
now.timestamp()
# Out:
# 1770399032.116833

# %%
(now+timedelta(hours=1)).timestamp()
# Out:
# 1770402632.116833
